# %%
import requests
import urllib
import pdb
import time
import random
import time

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

chrome_options=Options()
chrome_options.add_argument("--blink-settings=imagesEnabled=false") # 이미지를 로드하지 않아 전체적인 페이지 로드 속도를 빠르게 하기.
chrome_options.add_argument("user-agent= Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36") # 유저 에이전트를 지정하여 크롤러라는 것을 숨기기.
chrome_options.add_argument("disable-gpu") # 그래픽 가속 사용 안함.
# chrome_options.add_argument("headless") # 창 없는 크롬으로 실행.

# %%
def get_html(url):
    # URL 인코딩이 필요한 이유: http://regularmotion.kr/url-encoding-url/
    temp = requests.get(url)
    
    if temp.status_code == 200:
        
        html = temp.text 
    
    else:
        print("페이지가 정상적으로 로드 되지 못 하였습니다.")
        
        html = ""    
    
    return (html, temp.status_code)

querys = ["흡연 수명", "광고 매출", "운동 건강", "더위 전기료", "성실 성공"]

korean = {}

for query in querys:
    
    all_ = []
    
    for i in range(50):
        query = urllib.parse.quote("'흡연' '수명'")

        url = "https://www.google.co.kr/search?q=" + query + "&newwindow=1&ei=WXCkW5v4DIKj8AWR_KzACA&start=" + str(10 * i) + "&sa=N&biw=1142&bih=755"

        html, status_code = get_html(url)

        if status_code != 200:
            pdb.set_trace()

        soup = BeautifulSoup(html, "html.parser")

        texts = soup.select("h3.r > a")

        temp = list(map(lambda text: text.text, texts))

        all_ = all_.extend(temp)
        
        time.sleep(5)
    
        print(query + "의 " + str(i+1) + "번째 페이지까지 완료 되었습니다.")

    korean[query] = all_
# Out:
# %27%ED%9D%A1%EC%97%B0%27%20%27%EC%88%98%EB%AA%85%27의 1번째 페이지까지 완료 되었습니다.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-227-6b83f7caab30> in <module>()
#      38         temp = list(map(lambda text: text.text, texts))
#      39
# ---> 40         all_ = all_.extend(temp)
#      41
#      42         time.sleep(5)
#
# AttributeError: 'NoneType' object has no attribute 'extend'

# %%
driver = webdriver.Chrome("/Users/ku/chromedriver", chrome_options=chrome_options)

driver.implicitly_wait(5)

query = urllib.parse.quote("'흡연' '수명'")

smoke_korean = []

error_logs = []

for i in range(100):
    
    url = "https://www.google.co.kr/search?q=" + query + "&newwindow=1&ei=WXCkW5v4DIKj8AWR_KzACA&start=" + str(10 * i) + "&sa=N&biw=1142&bih=755&filter=0"

    driver.get(url)

    driver.implicitly_wait(5)

    try:
        web_ele = driver.find_elements_by_css_selector("div > h3 > a")
        
        temp_texts = list(map(lambda text: text.text, web_ele))   
        
        smoke_korean.extend(temp_texts)

    except:
        error_logs.appen(i)
        print("현재 페이지가 정상적으로 로드 되지 못 하였습니다. 에러 로그에 추가하고 다음 페이지로 넘어가겠습니다.")
    
    print(str(i+1) + "번째 페이지까지 완료되었습니다.")
    
    time.sleep(2)
    
print(smoke_korean)
# Out:
# 1번째 페이지까지 완료되었습니다.
# 2번째 페이지까지 완료되었습니다.
# 3번째 페이지까지 완료되었습니다.
# 4번째 페이지까지 완료되었습니다.
# 5번째 페이지까지 완료되었습니다.
# 6번째 페이지까지 완료되었습니다.
# 7번째 페이지까지 완료되었습니다.
# 8번째 페이지까지 완료되었습니다.
# 9번째 페이지까지 완료되었습니다.
# 10번째 페이지까지 완료되었습니다.
# 11번째 페이지까지 완료되었습니다.
# 12번째 페이지까지 완료되었습니다.
# 13번째 페이지까지 완료되었습니다.
# 14번째 페이지까지 완료되었습니다.
# 15번째 페이지까지 완료되었습니다.
# 16번째 페이지까지 완료되었습니다.
# 17번째 페이지까지 완료되었습니다.
# 18번째 페이지까지 완료되었습니다.
# 19번째 페이지까지 완료되었습니다.
# 20번째 페이지까지 완료되었습니다.
# 21번째 페이지까지 완료되었습니다.
# 22번째 페이지까지 완료되었습니다.
# 23번째 페이지까지 완료되었습니다.
# 24번째 페이지까지 완료되었습니다.
# 25번째 페이지까지 완료되었습니다.
# 26번째 페이지까지 완료되었습니다.
# 27번째 페이지까지 완료되었습니다.
# 28번째 페이지까지 완료되었습니다.
# 29번째 페이지까지 완료되었습니다.
# 30번째 페이지까지 완료되었습니다.
# 31번째 페이지까지 완료되었습니다.
# 32번째 페이지까지 완료되었습니다.
# 33번째 페이지까지 완료되었습니다.
# 34번째 페이지까지 완료되었습니다.
# 35번째 페이지까지 완료되었습니다.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
def get_html(url):
    # URL 인코딩이 필요한 이유: http://regularmotion.kr/url-encoding-url/
    temp = requests.get(url)
    
    if temp.status_code == 200:
        html = temp.text 
    else:
        print("페이지가 정상적으로 로드 되지 못 하였습니다.")
        html = ""    
    
    return (html, temp.status_code)

smoke_korean = []
for i in range(100):
    query = urllib.parse.quote("흡연 수명")
    url = "https://www.google.co.kr/search?q=" + query + "&newwindow=1&ei=WXCkW5v4DIKj8AWR_KzACA&start=" + str(10 * i) + "&sa=N&biw=1142&bih=755"
    html, status_code = get_html(url)
    
    if status_code != 200:
        pdb.set_trace()
    
    soup = BeautifulSoup(html, "html.parser")
    texts = soup.select("h3.r > a")

    temp = list(map(lambda text: text.text, texts))
    smoke_korean.extend(temp)
    
    print(str(i+1), "번째 페이지까지 완료 되었습니다.")
